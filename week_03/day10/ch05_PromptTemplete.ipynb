# %%
# !pip --version
# Out:
# pip 26.2.1 from D:\in0902\ex0914\.venv\Lib\site-packages\pip (python 3.12)

# %%
import os
from dotenv import load_dotenv
from langchain_teddynote import logging

# API KEY 정보로드
load_dotenv()
logging.langsmith("ch05_PromptTemplete.ipynb")

# langchain_teddynote가 US 엔드포인트로 덮어쓰므로, .env의 EU 엔드포인트로 복구
os.environ["LANGSMITH_ENDPOINT"] = "https://eu.api.smith.langchain.com"
# Out:
# LangSmith 추적을 시작합니다.
# [프로젝트명]
# ch05_PromptTemplete.ipynb

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI()

# %%
from langchain_core.prompts import PromptTemplate

template = "{country}의 수도는 어디인가요?"

prompt = PromptTemplate.from_template(template)
prompt
# Out:
# PromptTemplate(input_variables=['country'], input_types={}, partial_variables={}, template='{country}의 수도는 어디인가요?')

# %%
# prompt 생성 . format 메서드를 이용하여 변수에 값을 넣어줌

prompt = prompt.format(country="일본")
prompt
# Out:
# '일본의 수도는 어디인가요?'

# %%
template = "{country}의 수도는 어디인가요?" # template 정의

#from_templete 메서드를 이용하여 PromptTemplete 객체 생성
prompt = PromptTemplate.from_template(template)

chain = prompt | llm # chain 생성

# country 변수에 입력된 값이 자동으로 치환되어 수행됨

chain.invoke("일본").content
# Out:
# '일본의 수도는 도쿄(Tokyo)입니다.'

# %%
template = "{country}의 수도는 어디인가요 ?" #template 정의

#PromptTemplete 객체를 활용하여 prompt_template 생성

prompt = PromptTemplate(
    template=template,
    input_variables=["country"],
)

prompt
# Out:
# PromptTemplate(input_variables=['country'], input_types={}, partial_variables={}, template='{country}의 수도는 어디인가요 ?')

# %%
prompt.format(country="인도")
# Out:
# '인도의 수도는 어디인가요 ?'
