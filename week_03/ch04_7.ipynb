# %%
# !pip --version
# Out:
# pip 26.2.1 from D:\in0902\ex0914\.venv\Lib\site-packages\pip (python 3.12)

# %%
from dotenv import load_dotenv

# API KEY 정보로드
load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
model = ChatOpenAI()

prompt = PromptTemplate.from_template("{topic}에 대하여 3문장으로 설명해줘.")
# 프롬프트와 모델을 연결하여 대화 체인을 생성합니다.

chain = prompt | model | StrOutputParser()

# %%
chain
# Out:
# PromptTemplate(input_variables=['topic'], input_types={}, partial_variables={}, template='{topic}에 대하여 3문장으로 설명해줘.')
# | ChatOpenAI(metadata={'lc_versions': {'langchain-core': '1.6.3', 'langchain': '1.4.0', 'langchain-openai': '1.6.2'}}, profile={'name': 'GPT-3.5-turbo', 'status': 'deprecated', 'release_date': '2023-03-01', 'last_updated': '2023-11-06', 'open_weights': False, 'max_input_tokens': 16385, 'max_output_tokens': 4096, 'text_inputs': True, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': False, 'structured_output': False, 'attachment': False, 'temperature': True, 'image_url_inputs': False, 'pdf_inputs': False, 'pdf_tool_message': False, 'image_tool_message': False, 'tool_choice': True, 'tool_call_streaming': True}, client=<openai.resources.chat.completions.completions.Completions object at 0x0000023342143B30>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x0000023342BF3620>, root_client=<openai.OpenAI object at 0x0000023342117AD0>, root_async_client=<openai.AsyncOpenAI object at 0x0000023342AC7D70>, model_kwargs={}, openai_api_key=SecretStr('**********'), stream_usage=True, stream_chunk_timeout=120.0)
# | StrOutputParser()

# %%
chain.batch([{"topic":"ChatGPT"}, {"topic":"Instagram"}])
# Out:
# ['ChatGPT는 인공지능 챗봇으로 자연어 처리 및 대화 기능을 제공합니다. 사용자들은 ChatGPT를 통해 질문에 답변을 받거나 대화를 나눌 수 있습니다. 고급 챗봇 기능을 활용하여 여러 분야에서 유용하게 활용될 수 있습니다.',
#  'Instagram은 사진과 동영상을 공유하고 소셜 네트워크를 형성하는 앱이다. 다양한 필터와 효과를 이용하여 사진을 편집하고 팔로우한 사람들과 상호 소통할 수 있다. 해시태그를 통해 관심사에 맞는 게시물을 찾을 수 있으며, 인플루언서나 브랜드들과의 협업으로 다양한 콘텐츠를 공유하기도 한다.']

# %%
answer = chain.batch([{"topic":"ChatGPT"}, {"topic":"Instargram"}])
print(answer)
print(answer[0])
# Out:
# ['ChatGPT는 인공지능 챗봇으로, 사람과 대화하는 데 사용됩니다. 감정을 이해하고 다양한 주제에 대해 대화할 수 있으며, 사용자의 질문에 답변하고 정보를 제공할 수 있습니다. 머신 러닝과 자연어 처리 기술을 사용하여 성능을 끌어올려 지속적으로 개선되고 있습니다.', 'Instagram은 SNS 플랫폼으로 사진과 동영상을 공유하는 앱이다. 사용자는 팔로워들과 소통하고 콘텐츠를 공유할 수 있다. 또한 다양한 필터와 편집 기능을 제공하여 사진을 더욱 멋지게 편집할 수 있다.']
# ChatGPT는 인공지능 챗봇으로, 사람과 대화하는 데 사용됩니다. 감정을 이해하고 다양한 주제에 대해 대화할 수 있으며, 사용자의 질문에 답변하고 정보를 제공할 수 있습니다. 머신 러닝과 자연어 처리 기술을 사용하여 성능을 끌어올려 지속적으로 개선되고 있습니다.

# %%
# "max_concurrency": 3 동시에 세개씩 처리함.
chain.batch(
    [
        {"topic": "ChatGPT"},
        {"topic": "Instagram"},
        {"topic": "멀티모달"},
        {"topic": "프로그래밍"},
        {"topic": "머신러닝"},
    ],
    config={"max_concurrency": 3},
)
# Out:
# ['ChatGPT는 자연어 처리 모델로, 대화 인터페이스를 통해 다양한 주제에 관한 정보를 제공합니다. 이 모델은 사용자와 자연스러운 대화를 나누어 질문에 대한 답변을 제공하거나 솔루션을 제시합니다. 또한 ChatGPT는 신속하고 정확한 정보를 제공하여 사용자의 궁금증을 해결해 줍니다.',
#  'Instagram은 사진과 동영상을 공유하고 소셜 네트워크 서비스를 이용할 수 있는 앱이다. 사용자들은 팔로워들과 소통하며 콘텐츠를 공유할 수 있고, 해시태그를 통해 관심사에 맞는 게시물을 찾을 수 있다. 인스타그램 스토리, 릴스, IGTV 등 다양한 기능을 활용해 더 다채로운 콘텐츠를 제작하고 소통할 수 있다.',
#  '멀티모달은 여러 가지 다른 형태의 통신 매체를 활용하여 정보를 전달하거나 의사소통하는 방법을 말합니다. 이는 텍스트, 음성, 이미지, 영상 등 다양한 매체를 통해 사용자에게 정보를 제공함으로써 더 풍부한 경험을 제공할 수 있습니다. 또한 멀티모달은 사용자의 다양한 요구에 맞춰 다양한 형식으로 정보를 제공함으로써 효과적인 의사소통을 이룰 수 있습니다.',
#  '프로그래밍은 컴퓨터에게 실행을 지시하기 위해 일련의 명령을 작성하는 과정이다.\n일반적으로 특정 프로그래밍 언어를 사용하여 문제를 해결하고, 원하는 결과를 얻기 위해 코드를 작성한다.\n효율적이고 정확한 프로그래밍은 좋은 애플리케이션 개발과 문제 해결에 중요한 역할을 한다.',
#  '머신러닝은 컴퓨터 시스템에 데이터를 기반으로 학습하고 패턴을 발견하는 인공지능 기술이다. 이를 통해 컴퓨터는 데이터를 분석하고 예측하는 능력을 향상시키며, 다양한 분야에서 활용되고 있다. 빅데이터와 함께 혁신적인 기술과 서비스를 제공하는 중요한 역할을 하고 있으며, 미래 산업과 기술 발전에 기반을 제공한다.']
