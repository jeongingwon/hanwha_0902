# %%
#!pip --version
# Out:
# pip 26.2.1 from D:\in0902\ex0914\.venv\Lib\site-packages\pip (python 3.12)

# %%
from dotenv import load_dotenv

# API KEY 정보로드
load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
prompt = PromptTemplate.from_template("{topic} 에 대해 쉽게 설명해주세요.")
model = ChatOpenAI()

input = {"topic":"인공지능 모델의 학습 원리"}

# %%
print(prompt)
print(input)
# Out:
# input_variables=['topic'] input_types={} partial_variables={} template='{topic} 에 대해 쉽게 설명해주세요.'
# {'topic': '인공지능 모델의 학습 원리'}

# %%
output_parser = StrOutputParser()
output_parser
# Out:
# StrOutputParser()

# %%
chain = prompt | model | output_parser

# %%
# invoke : 문자열로 된 답변 얻음.
input = {"topic": "인공지능 모델의 학습 원리"}
chain.invoke(input)
# Out:
# '인공지능 모델의 학습 원리는 데이터를 입력으로 받아 모델이 내재된 패턴을 학습하고 결과를 예측하도록 하는 과정입니다. 모델은 입력 데이터를 처리하고 내부의 가중치를 조정해가며 학습을 반복하면서 성능을 개선해나갑니다. 이 과정은 일반적으로 손실 함수를 사용해 모델의 예측값과 실제 값 사이의 차이를 최소화하는 방향으로 진행됩니다. 더 많은 데이터를 학습시키고 더 복잡한 모델을 사용함으로써 모델의 성능을 높일 수 있습니다.'

# %%
template = """
당신은 영어를 가르치는 10년차 일본어 선생님입니다. 주어진 상황에 맞는 영어 회화를 작성해 주세요.
양식은 [FORMAT]을 참고하여 작성해 주세요.

#상황:
{question}

#FORMAT:
- 영어 회화:
- 한글 해석:
"""

# %%
# 프롬프트 템플릿을 이용하여 프롬프트를 생성.
prompt = PromptTemplate.from_template(template)

# ChatOpenAI 챗모델을 초기화.
model = ChatOpenAI(model_name="gpt-4o-mini")

# 문자열 출력 파서를 초기화.
output_parser = StrOutputParser()

# %%
# 체인을 구성합니다.
chain = prompt | model | output_parser

# %%
chain.invoke({"question": "저는 식당에 가서 음식을 주문하고 싶어요"})
# Out:
# '- 영어 회화:\nCustomer: Hi, can I see the menu, please?  \nWaiter: Sure! Here you go. What would you like to order?  \nCustomer: I’d like to have the sushi platter and a miso soup, please.  \nWaiter: Great choices! Would you like anything to drink?  \nCustomer: Yes, I’d like a green tea, please.  \nWaiter: Perfect! I’ll bring that right out for you.\n\n- 한글 해석:\n고객: 안녕하세요, 메뉴 좀 보여주시겠어요?  \n웨이터: 물론입니다! 여기 있습니다. 무엇을 주문하시겠어요?  \n고객: 초밥 플래터와 미소된장국을 주문하고 싶습니다.  \n웨이터: 훌륭한 선택이에요! 음료는 무엇을 드릴까요?  \n고객: 네, 녹차 하나 주세요.  \n웨이터: 완벽합니다! 바로 가져다 드리겠습니다.'
