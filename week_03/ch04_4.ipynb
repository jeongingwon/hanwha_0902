# %%
# !pip --version
# Out:
# pip 26.2.1 from D:\in0902\ex0914\.venv\Lib\site-packages\pip (python 3.12)

# %%
from dotenv import load_dotenv

# API KEY 정보로드
load_dotenv()
# Out:
# True

# %%
import logging
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage
from langchain_teddynote.messages import stream_response

# %%
# 매 실행마다, 반드시 로그파일을 확인하자~
# 여러번에 걸쳐 오류를 하나하나 해결하며, 결과를 도출해 나가는 방법을 연습해 보자. 

# Python logging 파일 설정 (app.log 파일로 저장)
logging.basicConfig(
    filename="app.log",             # 저장될 로그 파일 이름
    level=logging.INFO,             # 로깅 레벨 (INFO, DEBUG, ERROR 등)
    format="%(asctime)s - %(levelname)s - %(message)s", # 로그 포맷 (시간 - 레벨 - 메시지)
    encoding="utf-8"                # 한글 깨짐 방지
)

# 로컬 경로의 로그파일에 기록하기
logger = logging.getLogger("MyMultimodalApp")

# 로깅 시작 기록
logger.info("LangSmith 연동 및 애플리케이션 시작2")

try:
    # 멀티모달 LLM 선언
    multimodal_llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)

    IMAGE_URL = "https://t3.ftcdn.net/jpg/03/77/33/96/360_F_377339633_Rtv9I77sSmSNcev8bEcnVxTHrXB4nRJ5.jpg"
    prompt = "이미지의 내용을 한국어로 상세히 설명해 주세요."

    logger.info(f"요청 전송 - Prompt: {prompt} / Image: {IMAGE_URL}")

    # 메시지 생성 및 멀티모달 호출
    message = HumanMessage(
        content=[
            {"type": "text", "text": prompt},
            {"type": "image_url", "image_url": {"url": IMAGE_URL}},
        ]
    )

    # 스트리밍 및 응답 기록
    answer = multimodal_llm.stream([message])
    
    logger.info("답변 수신 및 스트리밍 시작")
    stream_response(answer)
    logger.info("답변 처리 완료")

except Exception as e:
    # 에러 발생 시 로그 파일에 에러 기록
    logger.error(f"실행 중 에러 발생: {str(e)}", exc_info=True)
# Out:
# 이 이미지는 표 형식으로 구성된 데이터입니다. 표의 제목은 "TABLE 001: LOREM IPSUM DOLOR AMIS ENIMA ACCUMMER TUNA"입니다. 표는 여러 열로 나뉘어 있으며, 각 열은 다음과 같은 항목을 포함하고 있습니다:
#
# 1. **첫 번째 열**: 항목의 이름 또는 설명이 들어 있습니다.
# 2. **두 번째 열 (Loremis)**: 숫자 데이터가 포함되어 있으며, 각 항목에 대한 특정 값을 나타냅니다.
# 3. **세 번째 열 (Amis terim)**: 백분율로 표시된 데이터가 포함되어 있습니다.
# 4. **네 번째 열 (Gato lepis)**: "YES" 또는 "NO"로 표시된 항목이 있으며, 특정 조건을 나타냅니다.
# 5. **다섯 번째 열 (Tortores)**: 가격 또는 비용을 나타내는 숫자가 포함되어 있습니다.
#
# 각 행은 서로 다른 항목에 대한 정보를 제공하며, 일부 항목은 특정 조건에 따라 "YES" 또는 "NO"로 구분됩니다. 표의 하단에는 추가적인 설명이 포함되어 있어, 데이터의 출처나 관련 정보를 제공하는 것으로 보입니다.
