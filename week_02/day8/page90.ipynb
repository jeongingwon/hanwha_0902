# %%
from openai import OpenAI

# %%
client = OpenAI()


response = client.responses.create(
    model= "gpt-5-mini",
    input= "API키 연결 테스트입니다. '정상 연결'이라고만 답해주세요."
)

# %%
print(response.output_text)
# Out:
# 정상 연결

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    temperature=0.1,
    Model_name = "gpt=4o-mini"
)
# Out:
# d:\in0902\ex0911\.venv\Lib\site-packages\IPython\core\interactiveshell.py:3762: UserWarning: WARNING! Model_name is not default parameter.
#                 Model_name was transferred to model_kwargs.
#                 Please confirm that Model_name is what you intended.
#   if await self.run_code(code, result, async_=asy):

# %%
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI

load_dotenv()

llm = ChatOpenAI(
    model="gpt-5-mini"
)

question = "대한민국의 수도는 어디인가요?"

response = llm.invoke(question)

print(f"[답변]: {response.content}")
# Out:
# [답변]: 대한민국의 수도는 서울특별시(서울)입니다. 다만 일부 중앙행정기관은 세종특별자치시로 이전해 행정 기능의 일부가 세종에 있기도 합니다.

# %%
import os
from dotenv import load_dotenv

load_dotenv()

api_key = os.getenv("GEMINI_API_KEY")

if not api_key:
    raise ValueError("❌ GEMINI_API_KEY를 찾을 수 없습니다.")

print("✅ Gemini API Key가 연결되었습니다.")
# Out:
# ✅ Gemini API Key가 연결되었습니다.

# %%
from google import genai

client = genai.Client(api_key=api_key)

# %%
response = client.models.generate_content(
    model="gemini-3.6-flash",
    contents="대한민국의 수도는 어디인가요?"
)

print(response.text)
# Out:
# 대한민국의 수도는 **서울**입니다.
